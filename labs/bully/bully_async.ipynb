# %%
#Asynchroniczność = współbieżne wykonywanie wielu zadań bez blokowania CPU.

#Wszystkie procesy (1, 2, 3, 4) działają współbieżnie — tzn. każdy ma własne zadanie (asyncio.Task) i niezależnie reaguje na wiadomości, awarie, heartbeat itp.
#Nie ma wątków ani procesów systemowych — tylko asynchroniczne „mikrozadania”, które współdzielą jedną pętlę zdarzeń (asyncio).

#process_task(pid, stop_event) - funkcja symuluje pojedyńczy proces

#async def nazwaFunkcji() - deklaruje funkcje asynchroniczna
#wywolanie funkcji asynchronicznej -> await nazwaFunkcji()
#await asyncio.sleep(0.1) - chwilowa pausa funkcji asynchronicznej
#asyncio.create_task(process_task(1)) - uruchamia funkcję asynchroniczną w tle, bez czekania na jej wynik.

# %%
import asyncio
import random
from typing import Dict, Optional, Tuple, List

# Parametry domyślne 
PROCESS_IDS: List[int] = [1, 2, 3, 4]   # większy = silniejszy
STEP_SEC: float = 0.1                   # "krok" czasu logicznego
HEARTBEAT_INTERVAL: float = 0.3         # co ile sekund lider bije heartbeat
HEARTBEAT_TIMEOUT: float  = 1.0         # timeout na heartbeat
PROB_CRASH: float = 0.02                # prawdopodobieństwo awarii w kroku
PROB_RECOVER: float = 0.01              # prawdopodobieństwo powrotu w kroku
SIM_STEPS: int = 400                    # liczba kroków (całkowity czas ≈ SIM_STEPS*STEP_SEC)
RANDOM_SEED: int = 42
STRICT_BULLY_ON_RECOVERY: bool = True   # po powrocie proces natychmiast inicjuje wybory

# =====================
# Zmienne systemowe (resetowane w main())
# =====================
mailboxes: Dict[int, asyncio.Queue] = {}
alive: Dict[int, bool] = {}
last_heartbeat: Optional[float] = None
current_leader: Optional[int] = None
leader_lock = asyncio.Lock()  # chroni current_leader & last_heartbeat
start_time_monotonic: Optional[float] = None  # do eleganckiego czasu w logach


def sim_time() -> float:
    """Czas symulacji względem startu pętli."""
    if start_time_monotonic is None:
        return 0.0
    return round(asyncio.get_running_loop().time() - start_time_monotonic, 2)

async def send(to: int, msg: Tuple[str, int]):
    await mailboxes[to].put(msg)

async def broadcast(msg: Tuple[str, int]):
    for p in PROCESS_IDS:
        await send(p, msg)

def log(msg: str):
    print(f"[{sim_time():5.2f}] {msg}")

async def check_and_maybe_start_election(pid: int):
    global current_leader, last_heartbeat
    if not alive.get(pid, False):
        return

    async with leader_lock:
        no_leader = current_leader is None
        hb_timed_out = (last_heartbeat is None) or (sim_time() - last_heartbeat > HEARTBEAT_TIMEOUT)

    if no_leader or hb_timed_out:
        higher = [p for p in PROCESS_IDS if p > pid and alive.get(p, False)]
        if not higher:
            async with leader_lock:
                current_leader = pid
                last_heartbeat = sim_time()
            await broadcast(("COORDINATOR", pid))
            log(f"Proces {pid}: ogłaszam się LIDEREM (brak silniejszych żywych)")
        else:
            for p in higher:
                await send(p, ("ELECTION", pid))
            log(f"Proces {pid}: rozpoczął ELECTION -> wysłano do {higher}")

async def handle_mailbox(pid: int):
    global current_leader, last_heartbeat

    if not alive.get(pid, False):
        # Opróżnij ewentualne zaległości
        try:
            while True:
                mailboxes[pid].get_nowait()
        except asyncio.QueueEmpty:
            pass
        return

    while True:
        try:
            typ, frm = mailboxes[pid].get_nowait()
        except asyncio.QueueEmpty:
            break

        if typ == "ELECTION":
            if pid > frm and alive.get(pid, False):
                await send(frm, ("OK", pid))
                log(f"Proces {pid}: OTRZYMAŁ ELECTION od {frm} -> wysyła OK i sam zaczyna wybory")
                await check_and_maybe_start_election(pid)
            else:
                log(f"Proces {pid}: OTRZYMAŁ ELECTION od {frm}, ale nie odpowiada (niższe ID lub nieżywy)")

        elif typ == "OK":
            log(f"Proces {pid}: OTRZYMAŁ OK od {frm} -> czeka na COORDINATOR")

        elif typ == "COORDINATOR":
            async with leader_lock:
                current_leader = frm
                last_heartbeat = sim_time()
            log(f"Proces {pid}: OTRZYMAŁ COORDINATOR -> nowy lider = {frm}")

        elif typ == "HEARTBEAT":
            async with leader_lock:
                if current_leader == frm or current_leader is None:
                    current_leader = frm
                    last_heartbeat = sim_time()
            log(f"Proces {pid}: OTRZYMAŁ HEARTBEAT od lidera {frm}")

async def process_task(pid: int, stop_event: asyncio.Event):
    # małe opóźnienie, żeby rozproszyć start
    await asyncio.sleep(STEP_SEC)
    await check_and_maybe_start_election(pid)

    while not stop_event.is_set():
        await handle_mailbox(pid)
        await check_and_maybe_start_election(pid)
        await asyncio.sleep(STEP_SEC)

async def leader_heartbeat_task(stop_event: asyncio.Event):
    global last_heartbeat
    last_sent = 0.0
    while not stop_event.is_set():
        await asyncio.sleep(STEP_SEC)
        async with leader_lock:
            leader = current_leader
        if leader is not None and alive.get(leader, False):
            if sim_time() - last_sent >= HEARTBEAT_INTERVAL:
                await broadcast(("HEARTBEAT", leader))
                last_sent = sim_time()
                async with leader_lock:
                    last_heartbeat = sim_time()
                log(f"Lider {leader}: wysyła HEARTBEAT")

async def faults_and_recoveries_task(stop_event: asyncio.Event):
    """Generator awarii/napraw w krokach symulacji."""
    steps = 0
    while not stop_event.is_set() and steps < SIM_STEPS:
        # Awarie
        for pid in PROCESS_IDS:
            if alive.get(pid, False) and random.random() < PROB_CRASH:
                alive[pid] = False
                log(f"!!! Proces {pid} ULEGŁ AWARII !!!")
                async with leader_lock:
                    if current_leader == pid:
                        log(f"!!! Lider {pid} padł — reszta wykryje po timeoutcie !!!")
        # Powroty
        for pid in PROCESS_IDS:
            if not alive.get(pid, True) and random.random() < PROB_RECOVER:
                alive[pid] = True
                log(f">>> Proces {pid} odzyskał sprawność")
                if STRICT_BULLY_ON_RECOVERY:
                    # Klasyczny bully: silniejszy po powrocie inicjuje wybory
                    await check_and_maybe_start_election(pid)
        steps += 1
        await asyncio.sleep(STEP_SEC)

    stop_event.set()

async def main():
    global mailboxes, alive, current_leader, last_heartbeat, start_time_monotonic

    random.seed(RANDOM_SEED)
    mailboxes = {pid: asyncio.Queue() for pid in PROCESS_IDS}
    alive = {pid: True for pid in PROCESS_IDS}
    current_leader = None
    last_heartbeat = None
    start_time_monotonic = asyncio.get_running_loop().time()

    stop_event = asyncio.Event()

    tasks = []
    for pid in PROCESS_IDS:
        tasks.append(asyncio.create_task(process_task(pid, stop_event), name=f"proc-{pid}"))
    tasks.append(asyncio.create_task(leader_heartbeat_task(stop_event), name="heartbeat"))
    tasks.append(asyncio.create_task(faults_and_recoveries_task(stop_event), name="faults"))

    await stop_event.wait()

    for t in tasks:
        t.cancel()
    await asyncio.gather(*tasks, return_exceptions=True)

# %%
async def start(
    *,
    sim_steps: Optional[int] = None,
    crash: Optional[float] = None,
    recover: Optional[float] = None,
    heartbeat_interval: Optional[float] = None,
    heartbeat_timeout: Optional[float] = None,
    step_sec: Optional[float] = None,
    strict_bully_on_recovery: Optional[bool] = None,
    process_ids: Optional[List[int]] = None,
    seed: Optional[int] = None,
):
    global SIM_STEPS, PROB_CRASH, PROB_RECOVER, HEARTBEAT_INTERVAL, HEARTBEAT_TIMEOUT
    global STEP_SEC, STRICT_BULLY_ON_RECOVERY, PROCESS_IDS, RANDOM_SEED

    if sim_steps is not None:
        SIM_STEPS = int(sim_steps)
    if crash is not None:
        PROB_CRASH = float(crash)
    if recover is not None:
        PROB_RECOVER = float(recover)
    if heartbeat_interval is not None:
        HEARTBEAT_INTERVAL = float(heartbeat_interval)
    if heartbeat_timeout is not None:
        HEARTBEAT_TIMEOUT = float(heartbeat_timeout)
    if step_sec is not None:
        STEP_SEC = float(step_sec)
    if strict_bully_on_recovery is not None:
        STRICT_BULLY_ON_RECOVERY = bool(strict_bully_on_recovery)
    if process_ids is not None:
        PROCESS_IDS = list(process_ids)
    if seed is not None:
        RANDOM_SEED = int(seed)

    await main()

# %%
await start(
    crash=0.08,          
    recover=0.02,        
    heartbeat_interval=0.3,
    heartbeat_timeout=0.8,
    strict_bully_on_recovery=True  # 
)
# Out:
# [ 0.00] !!! Proces 2 ULEGŁ AWARII !!!
# [ 0.09] Proces 1: rozpoczął ELECTION -> wysłano do [3, 4]
# [ 0.09] Proces 1: rozpoczął ELECTION -> wysłano do [3, 4]
# [ 0.09] Proces 3: rozpoczął ELECTION -> wysłano do [4]
# [ 0.09] Proces 3: OTRZYMAŁ ELECTION od 1 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 3: rozpoczął ELECTION -> wysłano do [4]
# [ 0.09] Proces 3: OTRZYMAŁ ELECTION od 1 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 3: rozpoczął ELECTION -> wysłano do [4]
# [ 0.09] Proces 3: rozpoczął ELECTION -> wysłano do [4]
# [ 0.09] Proces 4: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 1 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 1 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 3 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 3 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 3 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ ELECTION od 3 -> wysyła OK i sam zaczyna wybory
# [ 0.09] Proces 4: OTRZYMAŁ COORDINATOR -> nowy lider = 4
# [ 0.20] Proces 1: OTRZYMAŁ OK od 3 -> czeka na COORDINATOR
# [ 0.20] Proces 1: OTRZYMAŁ OK od 3 -> czeka na COORDINATOR
# [ 0.20] Proces 1: OTRZYMAŁ COORDINATOR -> nowy lider = 4
# [ 0.20] Proces 1: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.20] Proces 1: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.20] !!! Proces 1 ULEGŁ AWARII !!!
# [ 0.20] Proces 3: OTRZYMAŁ COORDINATOR -> nowy lider = 4
# [ 0.20] Proces 3: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.20] Proces 3: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.20] Proces 3: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.20] Proces 3: OTRZYMAŁ OK od 4 -> czeka na COORDINATOR
# [ 0.31] Lider 4: wysyła HEARTBEAT
# [ 0.31] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 4
# [ 0.42] !!! Proces 4 ULEGŁ AWARII !!!
# [ 0.42] !!! Lider 4 padł — reszta wykryje po timeoutcie !!!
# [ 1.19] Proces 3: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 1.19] Lider 3: wysyła HEARTBEAT
# [ 1.30] Proces 3: OTRZYMAŁ COORDINATOR -> nowy lider = 3
# [ 1.30] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 1.52] Lider 3: wysyła HEARTBEAT
# [ 1.52] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 1.73] !!! Proces 3 ULEGŁ AWARII !!!
# [ 1.73] !!! Lider 3 padł — reszta wykryje po timeoutcie !!!
# [ 2.59] >>> Proces 1 odzyskał sprawność
# [ 2.59] Proces 1: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 2.70] Proces 1: OTRZYMAŁ COORDINATOR -> nowy lider = 1
# [ 2.70] Lider 1: wysyła HEARTBEAT
# [ 2.81] Proces 1: OTRZYMAŁ HEARTBEAT od lidera 1
# [ 3.03] Lider 1: wysyła HEARTBEAT
# [ 3.14] Proces 1: OTRZYMAŁ HEARTBEAT od lidera 1
# [ 3.25] !!! Proces 1 ULEGŁ AWARII !!!
# [ 3.25] !!! Lider 1 padł — reszta wykryje po timeoutcie !!!
# [ 3.25] >>> Proces 2 odzyskał sprawność
# [ 4.02] Proces 2: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 4.02] Lider 2: wysyła HEARTBEAT
# [ 4.12] Proces 2: OTRZYMAŁ COORDINATOR -> nowy lider = 2
# [ 4.12] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [ 4.34] Lider 2: wysyła HEARTBEAT
# [ 4.34] !!! Proces 2 ULEGŁ AWARII !!!
# [ 4.34] !!! Lider 2 padł — reszta wykryje po timeoutcie !!!
# [ 7.06] >>> Proces 4 odzyskał sprawność
# [ 7.06] Proces 4: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 7.17] Lider 4: wysyła HEARTBEAT
# [ 7.17] Proces 4: OTRZYMAŁ COORDINATOR -> nowy lider = 4
# [ 7.17] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [ 7.50] Lider 4: wysyła HEARTBEAT
# [ 7.50] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [ 7.72] !!! Proces 4 ULEGŁ AWARII !!!
# [ 7.72] !!! Lider 4 padł — reszta wykryje po timeoutcie !!!
# [ 7.83] >>> Proces 3 odzyskał sprawność
# [ 8.36] Proces 3: ogłaszam się LIDEREM (brak silniejszych żywych)
# [ 8.36] Lider 3: wysyła HEARTBEAT
# [ 8.47] Proces 3: OTRZYMAŁ COORDINATOR -> nowy lider = 3
# [ 8.47] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 8.69] Lider 3: wysyła HEARTBEAT
# [ 8.80] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 9.02] Lider 3: wysyła HEARTBEAT
# [ 9.02] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 9.34] Lider 3: wysyła HEARTBEAT
# [ 9.45] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 9.67] Lider 3: wysyła HEARTBEAT
# [ 9.67] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [ 9.78] >>> Proces 1 odzyskał sprawność
# [10.00] !!! Proces 1 ULEGŁ AWARII !!!
# [10.00] Lider 3: wysyła HEARTBEAT
# [10.11] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [10.31] Lider 3: wysyła HEARTBEAT
# [10.42] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [10.42] >>> Proces 2 odzyskał sprawność
# [10.42] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [10.64] Lider 3: wysyła HEARTBEAT
# [10.64] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [10.64] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [10.97] Lider 3: wysyła HEARTBEAT
# [10.97] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.08] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.30] Lider 3: wysyła HEARTBEAT
# [11.30] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.30] >>> Proces 4 odzyskał sprawność
# [11.30] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.30] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.62] Lider 3: wysyła HEARTBEAT
# [11.73] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.73] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.73] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [11.95] Lider 3: wysyła HEARTBEAT
# [12.06] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.06] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.06] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.28] Lider 3: wysyła HEARTBEAT
# [12.28] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.28] !!! Proces 2 ULEGŁ AWARII !!!
# [12.39] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.50] !!! Proces 3 ULEGŁ AWARII !!!
# [12.50] !!! Lider 3 padł — reszta wykryje po timeoutcie !!!
# [12.72] >>> Proces 3 odzyskał sprawność
# [12.72] Lider 3: wysyła HEARTBEAT
# [12.81] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [12.81] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.05] Lider 3: wysyła HEARTBEAT
# [13.14] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.14] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.36] Lider 3: wysyła HEARTBEAT
# [13.36] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.48] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.69] Lider 3: wysyła HEARTBEAT
# [13.69] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [13.80] !!! Proces 3 ULEGŁ AWARII !!!
# [13.80] !!! Lider 3 padł — reszta wykryje po timeoutcie !!!
# [14.45] !!! Proces 4 ULEGŁ AWARII !!!
# [15.88] >>> Proces 3 odzyskał sprawność
# [15.88] Proces 3: ogłaszam się LIDEREM (brak silniejszych żywych)
# [15.88] Lider 3: wysyła HEARTBEAT
# [15.98] Proces 3: OTRZYMAŁ COORDINATOR -> nowy lider = 3
# [15.98] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [16.20] Lider 3: wysyła HEARTBEAT
# [16.20] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [16.53] Lider 3: wysyła HEARTBEAT
# [16.64] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [16.86] Lider 3: wysyła HEARTBEAT
# [16.97] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [16.97] >>> Proces 1 odzyskał sprawność
# [17.17] Lider 3: wysyła HEARTBEAT
# [17.17] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [17.28] Proces 1: OTRZYMAŁ HEARTBEAT od lidera 3
# [17.50] !!! Proces 1 ULEGŁ AWARII !!!
# [17.50] Lider 3: wysyła HEARTBEAT
# [17.61] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [17.83] Lider 3: wysyła HEARTBEAT
# [17.83] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.16] >>> Proces 4 odzyskał sprawność
# [18.16] Lider 3: wysyła HEARTBEAT
# [18.27] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.27] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.48] Lider 3: wysyła HEARTBEAT
# [18.59] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.59] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.81] Lider 3: wysyła HEARTBEAT
# [18.81] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [18.92] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.14] Lider 3: wysyła HEARTBEAT
# [19.14] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.25] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.47] Lider 3: wysyła HEARTBEAT
# [19.47] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.47] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.80] Lider 3: wysyła HEARTBEAT
# [19.91] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [19.91] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.12] Lider 3: wysyła HEARTBEAT
# [20.23] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.23] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.45] Lider 3: wysyła HEARTBEAT
# [20.45] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.56] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.77] Lider 3: wysyła HEARTBEAT
# [20.77] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [20.88] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.09] Lider 3: wysyła HEARTBEAT
# [21.09] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.09] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.42] Lider 3: wysyła HEARTBEAT
# [21.53] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.53] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.75] Lider 3: wysyła HEARTBEAT
# [21.86] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 3
# [21.86] !!! Proces 3 ULEGŁ AWARII !!!
# [21.86] !!! Lider 3 padł — reszta wykryje po timeoutcie !!!
# [21.86] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 3
# [22.08] !!! Proces 4 ULEGŁ AWARII !!!
# [23.50] >>> Proces 4 odzyskał sprawność
# [23.50] Proces 4: ogłaszam się LIDEREM (brak silniejszych żywych)
# [23.50] Lider 4: wysyła HEARTBEAT
# [23.50] Proces 4: OTRZYMAŁ COORDINATOR -> nowy lider = 4
# [23.50] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [23.83] Lider 4: wysyła HEARTBEAT
# [23.83] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [24.16] Lider 4: wysyła HEARTBEAT
# [24.27] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [24.48] Lider 4: wysyła HEARTBEAT
# [24.59] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [24.81] Lider 4: wysyła HEARTBEAT
# [24.92] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [25.14] Lider 4: wysyła HEARTBEAT
# [25.14] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [25.47] Lider 4: wysyła HEARTBEAT
# [25.47] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [25.58] >>> Proces 1 odzyskał sprawność
# [25.80] Lider 4: wysyła HEARTBEAT
# [25.89] Proces 1: OTRZYMAŁ HEARTBEAT od lidera 4
# [25.89] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [26.00] !!! Proces 1 ULEGŁ AWARII !!!
# [26.11] Lider 4: wysyła HEARTBEAT
# [26.22] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [26.44] Lider 4: wysyła HEARTBEAT
# [26.55] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [26.77] Lider 4: wysyła HEARTBEAT
# [26.77] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [27.09] Lider 4: wysyła HEARTBEAT
# [27.09] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [27.42] >>> Proces 2 odzyskał sprawność
# [27.42] Lider 4: wysyła HEARTBEAT
# [27.53] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 4
# [27.53] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 4
# [27.64] !!! Proces 4 ULEGŁ AWARII !!!
# [27.64] !!! Lider 4 padł — reszta wykryje po timeoutcie !!!
# [27.64] >>> Proces 1 odzyskał sprawność
# [28.08] !!! Proces 1 ULEGŁ AWARII !!!
# [28.41] Proces 2: ogłaszam się LIDEREM (brak silniejszych żywych)
# [28.52] Proces 2: OTRZYMAŁ COORDINATOR -> nowy lider = 2
# [28.52] Lider 2: wysyła HEARTBEAT
# [28.62] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [28.83] Lider 2: wysyła HEARTBEAT
# [28.94] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [29.16] Lider 2: wysyła HEARTBEAT
# [29.16] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [29.48] Lider 2: wysyła HEARTBEAT
# [29.48] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [29.81] Lider 2: wysyła HEARTBEAT
# [29.81] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [30.14] Lider 2: wysyła HEARTBEAT
# [30.25] >>> Proces 4 odzyskał sprawność
# [30.25] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [30.47] Lider 2: wysyła HEARTBEAT
# [30.47] !!! Proces 4 ULEGŁ AWARII !!!
# [30.58] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [30.80] Lider 2: wysyła HEARTBEAT
# [30.80] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [31.12] Lider 2: wysyła HEARTBEAT
# [31.12] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [31.23] >>> Proces 1 odzyskał sprawność
# [31.34] >>> Proces 4 odzyskał sprawność
# [31.45] Lider 2: wysyła HEARTBEAT
# [31.45] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [31.45] Proces 4: OTRZYMAŁ HEARTBEAT od lidera 2
# [31.56] Proces 1: OTRZYMAŁ HEARTBEAT od lidera 2
# [31.67] !!! Proces 2 ULEGŁ AWARII !!!
# [31.67] !!! Lider 2 padł — reszta wykryje po timeoutcie !!!
# [31.67] !!! Proces 4 ULEGŁ AWARII !!!
# [31.89] !!! Proces 1 ULEGŁ AWARII !!!
# [37.23] >>> Proces 2 odzyskał sprawność
# [37.23] Proces 2: ogłaszam się LIDEREM (brak silniejszych żywych)
# [37.23] Proces 2: OTRZYMAŁ COORDINATOR -> nowy lider = 2
# [37.23] Lider 2: wysyła HEARTBEAT
# [37.34] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [37.56] Lider 2: wysyła HEARTBEAT
# [37.67] >>> Proces 3 odzyskał sprawność
# [37.67] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [37.89] Lider 2: wysyła HEARTBEAT
# [37.89] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 2
# [37.89] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [38.00] !!! Proces 3 ULEGŁ AWARII !!!
# [38.20] >>> Proces 3 odzyskał sprawność
# [38.20] Lider 2: wysyła HEARTBEAT
# [38.20] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [38.31] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 2
# [38.53] Lider 2: wysyła HEARTBEAT
# [38.53] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [38.53] Proces 3: OTRZYMAŁ HEARTBEAT od lidera 2
# [38.86] !!! Proces 3 ULEGŁ AWARII !!!
# [38.86] Lider 2: wysyła HEARTBEAT
# [38.97] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [39.19] Lider 2: wysyła HEARTBEAT
# [39.30] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [39.52] Lider 2: wysyła HEARTBEAT
# [39.52] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [39.84] Lider 2: wysyła HEARTBEAT
# [39.84] Proces 2: OTRZYMAŁ HEARTBEAT od lidera 2
# [40.06] !!! Proces 2 ULEGŁ AWARII !!!
# [40.06] !!! Lider 2 padł — reszta wykryje po timeoutcie !!!
